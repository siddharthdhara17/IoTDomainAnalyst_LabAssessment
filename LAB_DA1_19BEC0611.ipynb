# %%
#The selected dataset is the list of Top 250 movies of all time according to the IMDB website
#This dataset has been selected from Kaggle
#19BEC0611- Venkata Siddharth Dhara

# %%
#In this step I am going to include the libraries which are needed for this assignment
#19BEC0611- Venkata Siddharth Dhara
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt                                    
import seaborn as sns                                             
# %matplotlib inline
sns.set()

from subprocess import check_output

# %%
#reading the dataset as dataframe df 
df=pd.read_csv('netflix_titles.csv')

# %% [markdown]
# # New Section

# %%
#Printing the head of the dataframe_19BEC0132
df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 15 columns]

# %%
#Printing the tail_19BEC0132
df.tail()
# Out:
#      show_id type title director  ... rating duration listed_in  description
# 8415     NaN  NaN   NaN      NaN  ...    NaN      NaN       NaN          NaN
# 8416     NaN  NaN   NaN      NaN  ...    NaN      NaN       NaN          NaN
# 8417     NaN  NaN   NaN      NaN  ...    NaN      NaN       NaN          NaN
# 8418     NaN  NaN   NaN      NaN  ...    NaN      NaN       NaN          NaN
# 8419     NaN  NaN   NaN      NaN  ...    NaN      NaN       NaN          NaN
#
# [5 rows x 15 columns]

# %%
#Apply conditions in any of the column and print the data that satisfies the condition
#Printing the data for The Godfather
df[(df['type']=='Movie')]
# Out:
#     show_id  ...                                        description
# 0        s1  ...  As her father nears the end of his life, filmm...
# 6        s7  ...  Equestria's divided. But a bright-eyed hero be...
# 7        s8  ...  On a photo shoot in Ghana, an American model s...
# 9       s10  ...  A woman adjusting to life after a loss contend...
# 12      s13  ...  After most of her family is murdered in a terr...
# ..      ...  ...                                                ...
# 142    s143  ...  While her at-risk students are reading classic...
# 143    s144  ...  Test pilot Hal Jordan harnesses glowing new po...
# 144    s145  ...  Grounded by his strict father, Kid risks life ...
# 145    s146  ...  Kid goes off to college with scholarship money...
# 146    s147  ...  After Kid gets engaged, Play plans to throw th...
#
# [89 rows x 15 columns]

# %%
#Apply conditions in any of the column and print the data that satisfies the condition_19BEC0611
df[(df['release_year']==2021)]
# Out:
#     show_id  ...                                        description
# 1        s2  ...  After crossing paths at a party, a Cape Town t...
# 2        s3  ...  To protect his family from a powerful drug lor...
# 3        s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4        s5  ...  In a city of coaching centers known to train I...
# 5        s6  ...  The arrival of a charismatic young priest brin...
# ..      ...  ...                                                ...
# 120    s121  ...  After a meteor crash, a group of zoo animals t...
# 125    s126  ...  A gay superspy and his scrappy LGBTQ squad fig...
# 130    s131  ...  At a summer performing arts program in New Yor...
# 132    s133  ...  A group of superheroes sets out to rid the wor...
# 147    s148  ...  Dale Brisby uses social media savvy and rodeo ...
#
# [68 rows x 15 columns]

# %%
#Apply conditions in two different columns and print the data if any of the condition is matched_19BEC0611
df[(df['release_year']>=2021) | (df['release_year']>=2020)]
# Out:
#     show_id  ...                                        description
# 0        s1  ...  As her father nears the end of his life, filmm...
# 1        s2  ...  After crossing paths at a party, a Cape Town t...
# 2        s3  ...  To protect his family from a powerful drug lor...
# 3        s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4        s5  ...  In a city of coaching centers known to train I...
# ..      ...  ...                                                ...
# 126    s127  ...  A couple must strive to remain resilient after...
# 130    s131  ...  At a summer performing arts program in New Yor...
# 132    s133  ...  A group of superheroes sets out to rid the wor...
# 147    s148  ...  Dale Brisby uses social media savvy and rodeo ...
# 148    s149  ...  When a family run barber shop in the heart of ...
#
# [80 rows x 15 columns]

# %%
#Apply conditions in two different columns and print the data if both the conditions are matched_19BEC0611
df[(df['release_year']==2020) & (df['type']=='Movie')]
# Out:
#     show_id  ...                                        description
# 0        s1  ...  As her father nears the end of his life, filmm...
# 16      s17  ...  Declassified documents reveal the post-WWII li...
# 78      s79  ...  A budding politician has devious plans to rise...
# 84      s85  ...  Twins are reunited as a good-hearted female ga...
# 103    s104  ...  A family faces destruction in a long-running c...
# 119    s120  ...  After meeting through a heated exchange on soc...
# 126    s127  ...  A couple must strive to remain resilient after...
#
# [7 rows x 15 columns]

# %%
#Make any of the column as index_19BEC0611
df.set_index("type",inplace = True)

# %%
df.head()
# Out:
#         show_id  ...                                        description
# type             ...
# Movie        s1  ...  As her father nears the end of his life, filmm...
# TV Show      s2  ...  After crossing paths at a party, a Cape Town t...
# TV Show      s3  ...  To protect his family from a powerful drug lor...
# TV Show      s4  ...  Feuds, flirtations and toilet talk go down amo...
# TV Show      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 14 columns]

# %%
#Plot any three columns in same graph_19BEC0611
sns.countplot(x='release_year', data=df, orient='h')

# %%
#Plot one column in a graph_19BEC0611
df["metascore"].plot()

# %%
#Plot bar chart for any of the column_19BEC0611
df.plot(x="imdb", y="score", kind="bar")

# %%
#Plot bar chart for any of the column_19BEC0611
df.plot("imdb", kind="bar")

# %%
df.hist(by='imdb', column = 'metascore')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9a754efb10>,
# ...
#       dtype=object)

# %%
df.imdb.value_counts().head(10).plot.bar()

# %%
#Plot stacked bar-chart for two columns_19BEC0611
df.plot(x="show_id", y=["imdb","metascore"], kind="bar", stacked=True)

# %%
#Plot histogram for any of the column_19BEC0611
df.plot(x="show_id", y=["imdb","metascore","score"],kind="hist")

# %%
#Plot histogram for any of the column_19BEC0611
df.plot(x="show_id", y=["imdb"],kind="hist",stacked=True)

# %%
##Plot histogram for two of the columns_19BEC0611
df.plot(x="show_id", y=["metascore","imdb"],kind="hist", stacked= True)
